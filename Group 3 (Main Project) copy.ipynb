# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# Load World Indicators CSV
with open ('/Users/danny_delatorre/Desktop/Project/Indicators.csv') as world_indicators:

# Read World Indicators File and store into Pandas data frame
    world_indicators = pd.read_csv('/Users/danny_delatorre/Desktop/Project/Indicators.csv')

# %%
# Load Athlete Events CSV
with open ('/Users/danny_delatorre/Desktop/Project/athlete_events.csv') as athlete_events:

# Read Purchasing File and store into Pandas data frame
    athlete_events = pd.read_csv('/Users/danny_delatorre/Desktop/Project/athlete_events.csv')

# %%
# World_Indicators DataFrame
world_indicators_data = pd.DataFrame(world_indicators)
world_indicators_data.head(5)
# Out:
#   CountryName CountryCode                                      IndicatorName  \
# 0  Arab World         ARB  Adolescent fertility rate (births per 1,000 wo...
# 1  Arab World         ARB  Age dependency ratio (% of working-age populat...
# 2  Arab World         ARB  Age dependency ratio, old (% of working-age po...
# 3  Arab World         ARB  Age dependency ratio, young (% of working-age ...
# 4  Arab World         ARB        Arms exports (SIPRI trend indicator values)
#
#     IndicatorCode  Year         Value
# 0     SP.ADO.TFRT  1960  1.335609e+02
# 1     SP.POP.DPND  1960  8.779760e+01
# 2  SP.POP.DPND.OL  1960  6.634579e+00
# 3  SP.POP.DPND.YG  1960  8.102333e+01
# 4  MS.MIL.XPRT.KD  1960  3.000000e+06

# %%
# Athlete_Events DataFrame
athlete_event_data = pd.DataFrame(athlete_events)

athlete_event_data.head(5)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
unique_items = world_indicators["CountryCode"].nunique()

world_indicators_df = pd.DataFrame({"Unique Codes":[unique_items]})

world_indicators_df
# Out:
#    Unique Codes
# 0           247

# %%
unique_items = athlete_events["Team"].nunique()
noc_count = athlete_events["NOC"].nunique()
total_athletes = athlete_events["Name"].nunique()
year = athlete_events["Year"].nunique()

athlete_events_df = pd.DataFrame({"Unique Teams":[unique_items],
                                   "Total Athletes":[total_athletes],
                                   "# of Events":[year],
                                  "noc": [noc_count]})

athlete_events_df
# Out:
#    Unique Teams  Total Athletes  # of Events  noc
# 0          1184          134732           35  230

# %%
#print(pd.merge(athlete_events, world_indicators, left_on='NOC', right_on='CountryCode').drop('CountryCode', axis=1)
# we need to make sure that they are conveted to the same data type 
#for row in world_indicators_df.iterrows():
#merged_df = pd.merge(athlete_event_data.head(6000), world_indicators_data.head(6000), left_on='NOC', right_on='CountryCode')

#merged_df.head(10)
GDP_per_cap = 'GDP per capita (current US$)'

def fun(GDP_per_cap):
    
    GDP = world_indicators_data['IndicatorName'].to_list()

    if (GDP_per_cap in GDP): 
    
       return True
    
    else: 
        
        return False
# Out:
# <function fun at 0x11c5a67a0>

# %%
W_I_GDP = world_indicators_data['IndicatorName'] == 'GDP per capita (current US$)'
W_I_GDP.head(1000)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: IndicatorName, Length: 1000, dtype: bool

# %%
columns = ['IndicatorName', 'Year', 'Value']
W_I_GDP = world_indicators_data.loc[world_indicators_data['IndicatorName'] == 'GDP per capita (current US$)', columns]
W_I_GDP.head()
# Out:
#                     IndicatorName  Year       Value
# 95   GDP per capita (current US$)  1960  457.464712
# 264  GDP per capita (current US$)  1960  146.814138
# 377  GDP per capita (current US$)  1960   89.319639
# 518  GDP per capita (current US$)  1960  924.571393
# 624  GDP per capita (current US$)  1960  648.223441
